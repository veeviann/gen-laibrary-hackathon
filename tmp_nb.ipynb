# %%
import pandas as pd

# %%
ecollection = pd.read_csv('data/external/active_ecollection.csv', index_col=0)
ecollection.head()
# Out:
#             Electronic Collection Id Electronic Collection Public Name  \
# MMS Id
# 99401002601                     None                               NaN
# 99460702601         6168549700002600   ProQuest LibCentral owned Ebook
# 99500102601         6168549700002600   ProQuest LibCentral owned Ebook
# 99500302601         6168549700002600   ProQuest LibCentral owned Ebook
# 99500602601         6168549700002600   ProQuest LibCentral owned Ebook
#
#                    Service Id      Portfolio Id Material Type  \
# MMS Id
# 99401002601                -1  5372259730002600       Journal
# 99460702601  6268549690002600  5341569480002600          Book
# 99500102601  6268549690002600  5341571120002600          Book
# 99500302601  6268549690002600  5341573010002600          Book
# 99500602601  6268549690002600  5341586940002600          Book
#
#                                                          Title
# MMS Id
# 99401002601                         The Singapore law gazette.
# ...

# %%
ecollection.shape
# Out:
# (929904, 6)

# %%
ecollection.iloc[:, 1].value_counts()
# Out:
# Ebook Central Academic Complete International Edition        196020
# SpringerLink Books - AutoHoldings                            141563
# DOAB Directory of Open Access Books                           61536
# JSTOR eBooks DDA Corpus Collection                            47661
# O'Reilly Online Learning: Academic/Public Library Edition     43270
#                                                               ...
# e-Duke Journals Scholarly Collections: Expanded 2021              1
# Edward Elgar Journals                                             1
# Duke University Press                                             1
# University of California Press Journals                           1
# Royal Society                                                     1
# Name: Electronic Collection Public Name, Length: 211, dtype: int64

# %%
ecollection.iloc[:, 4].value_counts()
# Out:
# Book               700947
# Journal            121520
# Streaming Video     53209
# Unknown             19097
# Proceeding          16319
# Series               6077
# Document             3917
# Video                3344
# Report               2558
# Newspaper            1649
# Map                  1016
# Wire                  144
# Conference             44
# Transcript             28
# Sound Recording        19
# Dissertation            9
# Database                3
# Data Set                2
# Musical Score           1
# Website                 1
# Name: Material Type, dtype: int64

# %%
chatlogs = pd.read_csv('data/external/chat_transcript_2023-01to2023-06-anonymized.csv', index_col=0)
chatlogs.head()
# Out:
#                 Email domain             Browser Operating System  \
# Chat ID
# 3082292  ***@mitb.smu.edu.sg  Chrome (108.0.0.0)          Windows
# 3082360       ***@smu.edu.sg  Chrome (108.0.0.0)          Windows
# 3082372   ***@dba.smu.edu.sg  Chrome (108.0.0.0)          Windows
# 3082470  ***@scis.smu.edu.sg     Safari (14.1.2)        Macintosh
# 3082483    ***@jd.smu.edu.sg     Firefox (108.0)          Windows
#
#                                                 User Agent  \
# Chat ID
# 3082292  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3082360  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3082372  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3082470  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 3082483  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...
#
#                                                   Referrer         Widget  \
# Chat ID
# 3082292         https://library.smu.edu.sg/services/alumni  Slide-out tab
# ...

# %%
chatlogs.shape
# Out:
# (1159, 23)

# %%
import seaborn as sns

# %%
sns.histplot(chatlogs['Message Count'])
# Out:
# <Axes: xlabel='Message Count', ylabel='Count'>

# %%
chatlogs['anon_transcript'].iloc[0]
# Out:
# '10:50:46 - PERSON_FIRSTNAME_2 PERSON_LASTNAME_2 : Hi\n10:50:48 - PERSON_FIRSTNAME_2 PERSON_LASTNAME_2 : how can i help you<br />\n10:51:36 - PERSON_FIRSTNAME_1 PERSON_LASTNAME_1 : Hi, I graduated from SMU in 2022. I would like to access the LKS library. What memberships do I have to apply for?\n10:52:01 - PERSON_FIRSTNAME_1 PERSON_LASTNAME_1 : I see both a SMU AA and a SMU library membership, and am confused\n10:52:19 - PERSON_FIRSTNAME_2 PERSON_LASTNAME_2 : Hi PERSON_FIRSTNAME_1, are you looking at just using the library spaces? or you need to borrow books and use some of the databases?<br />\n10:52:31 - PERSON_FIRSTNAME_1 PERSON_LASTNAME_1 : Just using the library spaces\n10:53:06 - PERSON_FIRSTNAME_2 PERSON_LASTNAME_2 : ok.. if that is the case.. all you need to do is just download the SMU Alumni app.... retrieve the SMU Alumni digital card, and you can use that to access the libraries<br />\n10:53:28 - PERSON_FIRSTNAME_2 PERSON_LASTNAME_2 : <a href="https://alumni.smu.edu.sg/ser
# ...

# %%
reading_list = pd.read_csv('data/external/reading_list.csv')
reading_list
# Out:
#                     User Group                             School  \
# 0                       MASTER      School of Information Systems
# 1                       MASTER      School of Information Systems
# 2                       MASTER  Lee Kong Chian School of Business
# 3                       MASTER  Lee Kong Chian School of Business
# 4                       MASTER  Lee Kong Chian School of Business
# ...                        ...                                ...
# 94885  NON-GRADUATING STUDENTS                             Others
# 94886  NON-GRADUATING STUDENTS                             Others
# 94887  NON-GRADUATING STUDENTS                             Others
# 94888  NON-GRADUATING STUDENTS                             Others
# 94889  NON-GRADUATING STUDENTS                             Others
#
#                                             Hashed Email  Course Year  \
# 0      84bf936dc7c137206e38dc7488399509cfbccea345250d...         2022
# ...

# %%
reading_list.columns
# Out:
# Index(['User Group', 'School', 'Hashed Email', 'Course Year',
#        'Academic Department', 'Course Instructor', 'Course Code',
#        'Course Name', 'Citation Material Type', 'Citation Title',
#        'Journal Title', 'Book Chapter Title', 'Author', 'Publication Date',
#        'Publisher'],
#       dtype='object')

# %%
readling_

# %%
reading_list['User Group'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
reading_list['School'].value_counts()
# Out:
# Lee Kong Chian School of Business    36720
# School of Social Sciences            22197
# School of Information Systems        11075
# School of Accountancy                 6823
# School of Law                         6644
# School of Economics                   6093
# Others                                5338
# Name: School, dtype: int64

# %%
base_url = "https://api-ap.hosted.exlibrisgroup.com"
